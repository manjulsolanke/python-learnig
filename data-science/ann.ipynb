# %% [markdown]
# ## Artifical Neural Network

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
os.getcwd()
import os
os.chdir('/Users/manjulsolanke/Documents/python-learnig/data-science/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-560175217.py in <cell line: 0>()
#       5 os.getcwd()
#       6 import os
# ----> 7 os.chdir('/Users/manjulsolanke/Documents/python-learnig/data-science')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/manjulsolanke/Documents/python-learnig/data-science'

# %%
tf.__version__
# Out:
# '2.19.0'

# %% [markdown]
# ### Part 1 Data Preprocessing

# %% [markdown]
# Importing the datasets

# %%
dataset = pd.read_csv('/Users/manjulsolanke/Documents/python-learnig/data-science/Churn_Modelling.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3576500599.py in <cell line: 0>()
# ----> 1 dataset = pd.read_csv('/Users/manjulsolanke/Documents/python-learnig/data-science/Churn_Modelling.csv')
#
# ...
