# %%
print("hello world")
# Out:
# hello world

# %%
def new_func():
    for i in range(1, 11):
        for j in range(1, i+1):
            print('*', end='')
        print()
new_func()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********

# %%
print("hello")
# Out:
# hello
